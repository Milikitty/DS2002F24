# %% [markdown]
# <a href="https://colab.research.google.com/github/Milikitty/DS2002F24/blob/main/acc_players_2324F_jhs5gq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Reading CSV files
import pandas as pd
import numpy as np

acc_players = pd.read_csv("/content/acc_players-2324F.csv")
acc_players.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4 Totals  \
# 0         Rk         Player      Class        Pos          School      G
# 1          1   Amaree Abram         SO          G    Georgia Tech     10
# 2          2   Sola Adebisi         FR          F   Florida State      7
# 3          3  Prince Aligbe         SO          F  Boston College     35
# 4          4     Abe Atiyeh         SR          G  Boston College      4
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12  \
# 0         MP        TRB        AST        STL  ...         TOV          PF
# 1        108         17         11          1  ...           9          10
# 2          9          1          1          0  ...           1           1
# 3        651        119         21         15  ...          30          51
# 4          6          0          0          0  ...           1           0
#
#   Unnamed: 13 Shooting Unnamed: 15 Unnamed: 16 Unnamed: 17 Advanced  \
# ...

# %%
#2 Basic analysis
acc_players['Unnamed: 13'] = pd.to_numeric(acc_players['Unnamed: 13'], errors='coerce')
acc_players['Unnamed: 13'] = acc_players['Unnamed: 13'].fillna(0)
acc_players['Unnamed: 13'] = acc_players['Unnamed: 13'].astype(int)
total_points = acc_players['Unnamed: 13'].sum()
print(total_points)
# Out:
# 38411

# %%
#2 Basic analysis
acc_players['Unnamed: 6'] = pd.to_numeric(acc_players['Unnamed: 6'], errors='coerce')
acc_players['Unnamed: 6'] = acc_players['Unnamed: 7'].fillna(0)
acc_players['Unnamed: 6'] = acc_players['Unnamed: 7'].astype(int)
top_minutes_player = acc_players.nlargest(1, 'Unnamed: 6')['Unnamed: 1']
print(top_minutes_player)
# Out:
# 6    Armando Bacot
# Name: Unnamed: 1, dtype: object

# %%
#2 Basic analysis
acc_players['Unnamed: 7'] = pd.to_numeric(acc_players['Unnamed: 7'], errors='coerce')
acc_players['Unnamed: 7'] = acc_players['Unnamed: 7'].fillna(0)
acc_players['Unnamed: 7'] = acc_players['Unnamed: 7'].astype(int)
top_5_rebounders = acc_players.nlargest(5, 'Unnamed: 7')['Unnamed: 1']
print(top_5_rebounders)
# Out:
# 6        Armando Bacot
# 179    Ian Schieffelin
# 91     Harrison Ingram
# 45      Mohamed Diarra
# 150      Norchad Omier
# Name: Unnamed: 1, dtype: object

# %%
#3 Player filtering
acc_players['Unnamed: 6'] = pd.to_numeric(acc_players['Unnamed: 6'], errors='coerce')
acc_players['Unnamed: 6'] = acc_players['Unnamed: 6'].fillna(0)
acc_players['Unnamed: 6'] = acc_players['Unnamed: 6'].astype(int)
filtered_players = acc_players.groupby('Unnamed: 1').agg(
    Filtered_Values=('Unnamed: 6', lambda x: list(x) if sum(x) > 500 else None)
).reset_index()

filtered_players = filtered_players.dropna(subset=['Filtered_Values'])
print(filtered_players)
# Out:
#          Unnamed: 1 Filtered_Values
# 9       Andrew Carr          [1138]
# 11     Andrew Rohde           [830]
# 13    Armando Bacot          [1123]
# 16      Baba Miller           [818]
# 18      Baye Ndongo           [805]
# ..              ...             ...
# 204    Tyler Nickel           [802]
# 205  Tyrese Proctor           [974]
# 206  Tyzhaun Claude           [557]
# 212    Wooga Poplar           [902]
# 214     Zack Austin           [746]
#
# [98 rows x 2 columns]

# %%
acc_players['Unnamed: 8'] = pd.to_numeric(acc_players['Unnamed: 8'], errors='coerce')
acc_players['Unnamed: 8'] = acc_players['Unnamed: 8'].fillna(0)
acc_players['Unnamed: 8'] = acc_players['Unnamed: 8'].astype(int)

top_assists = acc_players.groupby('Unnamed: 1').agg({'Unnamed: 8': 'sum'})
top_assists = top_assists.nlargest(3, 'Unnamed: 8')
print(top_assists)
# Out:
#                 Unnamed: 8
# Unnamed: 1
# Reece Beekman          212
# Jaeden Zackery         152
# Elliot Cadeau          150

# %%
acc_players['Unnamed: 10'] = pd.to_numeric(acc_players['Unnamed: 10'], errors='coerce')
acc_players['Unnamed: 10'] = acc_players['Unnamed: 10'].fillna(0)
acc_players['Unnamed: 10'] = acc_players['Unnamed: 10'].astype(int)

top_block = acc_players.groupby('Unnamed: 1').agg({'Unnamed: 10': 'sum'})
top_block = top_block.nlargest(3, 'Unnamed: 10')
print(top_block)
# Out:
#                Unnamed: 10
# Unnamed: 1
# Ryan Dunn               77
# Quinten Post            61
# Armando Bacot           56

# %%
#4 School Analysis
acc_players['Unnamed: 13'] = pd.to_numeric(acc_players['Unnamed: 13'], errors='coerce')
acc_players['Unnamed: 13'] = acc_players['Unnamed: 13'].fillna(0)
acc_players['Unnamed: 13'] = acc_players['Unnamed: 13'].astype(int)

acc_players['Unnamed: 8'] = pd.to_numeric(acc_players['Unnamed: 8'], errors='coerce')
acc_players['Unnamed: 8'] = acc_players['Unnamed: 8'].fillna(0)
acc_players['Unnamed: 8'] = acc_players['Unnamed: 8'].astype(int)

school_stats = acc_players.groupby('Unnamed: 4').agg({'Unnamed: 13': 'sum', 'Unnamed: 8': 'sum'})
school_stats
# Out:
#                 Unnamed: 13  Unnamed: 8
# Unnamed: 4
# Boston College         2667         509
# Clemson                2785         533
# Duke                   2830         551
# Florida State          2526         406
# Georgia Tech           2272         425
# Louisville             2304         356
# Miami (FL)             2424         454
# NC State               3101         536
# North Carolina         3032         536
# Notre Dame             2113         335
# Pittsburgh             2495         452
# School                    0           0
# Syracuse               2442         442
# Virginia               2140         509
# Virginia Tech          2547         514
# Wake Forest            2733         429

# %%
#4
school_rank = school_stats.sort_values(by='Unnamed: 13', ascending=False)
school_rank.head(3)
# Out:
#                            Unnamed: 13
# Unnamed: 4     Unnamed: 1
# North Carolina RJ Davis            784
# NC State       DJ Horne            677
# Clemson        PJ Hall             659

# %% [markdown]
# 1) I would say that this exercise has illustrated to me the importance of creating tidy datasets and avoiding jargon. I found that for later data analysis, there's an underappreciation of the impact unclear headers have for later data analysis. I would say that data analysis techniques have a great deal of place in a variety of fields and understanding how to manipulate large amounts of data in fields you may not be the most familiar with is a challenge that data scientists face. I would say in this exercise, I learned to tabulate a lot of data and manipulate data that is not necessarily clean. I had to manually force and coerce data sets into being into different formats such as integer formats. I would say that this exercise has illustrated the importance and utility of Pandas for dealing with large datasets, a very useful and versatile tool for dealing with datasets in a variety of settings.
#
# 2) What I learned from this experience was that filtering and manipulating data is easily the most challenging and time consuming aspect of data cleaning. It was difficult for me as someone not familiar with sports or basketball to understand the jargon that was present in the header. Additionally, the heading was done incorrectly so that you had text values in places where there should be no text. I had to employ techniques not really covered in class in order to clean up the data. Firstly, I had to create several data frames for several different purposes. I had to use aggregate functions in order to tabulate my data as this wasn't being done automatically. I often had to chunk the code and the questions in order to avoid the pitfalls of having huge code blocks that I had no idea where the issues were. Simply understanding the data was quite difficult and I had to look up common basketball abbreviation in order to make this work and for me to better understand the headers.
#
# 3) I would say that this exercise has shown the difficulty in data analysis in any field. It also underscores the importance of learning how to manage very very large and messy databases. I would say that for me, this experience with a data set that I'm not used to has given me the greater ability and flexibility to work outside of fields that I am most familiar with. Though, this also tells me that data is something that people in a variety of fields work with. As someone who keeps an open mind to the types of data science fields I want to go into, I would say this experience has given me some insight in to some of the work actual data scientists do and the broad applicability of data analysis techniques.
